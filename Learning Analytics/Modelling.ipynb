# %% [markdown]
# ## Analyzing Open University Learning Analytics Dataset
#
# ### Problem Statement
# ## Data Modelling
# Based on the given data of students enrolled in various courses identify the student who is at-risk so that suitable interventions can be taken to help students succeed.
#
# ***Part-4 : Data Modelling and Prediction***
#
# In this part we will try to model the data and predict the student at risk.

# %%
#importing Libraries
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# ML libraries
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm.libsvm import predict_proba
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve

# %%
# Reading Data
student_info = pd.read_csv('../studentInfo.csv')
student_assessment = pd.read_csv('../studentAssessment.csv')
student_registration = pd.read_csv('../studentRegistration.csv')
student_vle = pd.read_csv('../studentVle.csv')
assessments = pd.read_csv('../assessments.csv')
courses = pd.read_csv('../courses.csv')
vle = pd.read_csv('../vle.csv')

#check for the data
print('----- Rows -----')
print('Courses     : ',courses.shape[0])
print('Assessments : ',assessments.shape[0])
print('vle(Virtual Learning Environment) : ',vle.shape[0])
print('Student Info         : ',student_info.shape[0])
print('student Assessment   : ',student_assessment.shape[0])
print('student Registration : ',student_registration.shape[0])
print('student Vle          : ',student_vle.shape[0])
# Out:
# ----- Rows -----
# Courses     :  22
# Assessments :  206
# vle(Virtual Learning Environment) :  6364
# Student Info         :  32593
# student Assessment   :  173912
# student Registration :  32593
# student Vle          :  10655280

# %%
#Utilities
"""
Calculates sum based on the previous value
"""
def compute_weighted_sum(data, current_val, new_col):
    data[new_col] = data[current_val].cumsum()
    return data

# %%
"""
Get mean of the split data
"""
def split_mean(x):
    split_list = x.split('-')
    mean = (float(split_list[0])+float(split_list[1]))/2
    return mean

# %%
"""
Preprocessing Student_info
"""

def preprocess_student_info(data):
    data_pre = data.copy()
    data_pre['final_result'] = labelEncoder.fit_transform(data_pre['final_result'])
    #convert categorical columns 
    #----imd_band
    # Remove % first and replace '?' with 0 
    data_pre['imd_band'] =  data_pre['imd_band'].apply(lambda x : x.replace('%',''))
    data_pre['imd_band'] =  data_pre['imd_band'].apply(lambda x : '0' if x == '?' else x)
    #compute mean of the range and add them in seperate column
    data_pre['imd_band_mean'] = data_pre['imd_band'].apply(lambda x : 0 if x == '0' else split_mean(x))
    #----age_band
    # Replace '55<=' with 55 and other ranges with their mean 
    data_pre['age_band_mean'] =  data_pre['age_band'].apply(lambda x : 55 if x == '55<=' else split_mean(x))
    data_pre = data_pre[['code_module','code_presentation','id_student','gender','region','highest_education','num_of_prev_attempts','studied_credits','imd_band','imd_band_mean',
                         'age_band','age_band_mean','final_result']]
    return data_pre

# %%
#adding some more columns
assessments_stats = assessments.groupby(['code_module','code_presentation']).agg({'weight' : 'sum'})
assessments_stats.reset_index(level=[0,1], inplace=True)
assessments_stats.columns = ['code_module','code_presentation','total_marks']
assessments_stats = pd.merge(assessments, assessments_stats, how='left', on=['code_module','code_presentation'])
assessments_stats['percent_of_total'] = np.divide(assessments_stats['weight'],assessments_stats['total_marks'])*100
#assessments_stats.groupby(['code_module','code_presentation']).size()
assessments_stats = assessments_stats.groupby(['code_module','code_presentation']).apply(compute_weighted_sum, 'percent_of_total', 'weight_in_total')
student_assessments_all = pd.merge(student_assessment, assessments_stats, how = 'outer', on='id_assessment' )
# Dropping the null values
student_assessments_all = student_assessments_all.dropna()
student_assessments_all['score'] = np.where(student_assessments_all['score'] == '?', '0', student_assessments_all['score'])
student_assessments_all['score'] = pd.to_numeric(student_assessments_all['score'])
student_assessments_all['assessment_result'] = np.where(student_assessments_all['score'] >= 40, 1, 0)
student_assessments_all['score_weight'] = np.divide(student_assessments_all['score'],100)*student_assessments_all['percent_of_total']
student_assessments_all = student_assessments_all.dropna()
#student_assessments_all.id_student.nunique()
student_assessments_all = student_assessments_all.groupby(['code_module','code_presentation','id_student']).apply(compute_weighted_sum,'score_weight', 'score_in_total')
student_assessments_all = student_assessments_all[['code_module','code_presentation','id_student','id_assessment','assessment_type','date','date_submitted','is_banked',
                                                   'score','weight','percent_of_total','score_weight','weight_in_total','score_in_total','total_marks','assessment_result']]
#student_assessments_all[student_assessments_all['id_student'] == 63400]
student_assessments_all = student_assessments_all.dropna()
student_assessments_all[student_assessments_all['id_student'] == 63400]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
#      code_module code_presentation  id_student  id_assessment assessment_type  \
# 13           AAA             2013J     63400.0           1752             TMA
# 514          AAA             2013J     63400.0           1753             TMA
# 855          AAA             2013J     63400.0           1754             TMA
# 1045         AAA             2013J     63400.0           1755             TMA
# 1470         AAA             2013J     63400.0           1756             TMA
#
#        date  date_submitted  is_banked  score  weight  percent_of_total  \
# 13     19.0            19.0        0.0   83.0    10.0               5.0
# 514    54.0            54.0        0.0   42.0    20.0              10.0
# 855   117.0           117.0        0.0   78.0    20.0              10.0
# 1045  166.0           166.0        0.0   76.0    20.0              10.0
# 1470  215.0           215.0        0.0   79.0    30.0              15.0
#
#       score_weight  weight_in_total  score_in_total  total_marks  \
# 13            4.15              5.0            4.15        200.0
# 514           4.20             15.0            8.35        200.0
# 855           7.80             25.0           16.15        200.0
# 1045          7.60             35.0           23.75        200.0
# 1470         11.85             50.0           35.60        200.0
#
#       assessment_result
# 13                    1
# 514                   1
# 855                   1
# 1045                  1
# 1470                  1

# %%
### ----  get ddata model
student_clicks = student_vle.groupby(['id_student', 'code_module', 'code_presentation']).agg({'sum_click':['mean','sum']})
student_clicks.reset_index(level=[0,1,2], inplace=True)
student_clicks.columns = ['id_student', 'code_module', 'code_presentation', 'mean_clicks', 'sum_clicks']
#student_clicks
# merging student_clicks with student info
student_course_info = pd.merge(student_info,student_clicks, how='left', left_on=['id_student', 'code_module', 'code_presentation'],right_on=['id_student', 'code_module',
                                                                                                                                             'code_presentation'])
student_course_info = student_course_info[['code_module','code_presentation','id_student','gender','region','highest_education','imd_band','age_band','num_of_prev_attempts',
                                           'studied_credits','disability','mean_clicks','sum_clicks','final_result']]
student_course_info.reset_index(level=[0], inplace=True)
student_course_info.head()
# Out:
#    index code_module code_presentation  id_student gender  \
# 0      0         AAA             2013J       11391      M
# 1      1         AAA             2013J       28400      F
# 2      2         AAA             2013J       30268      F
# 3      3         AAA             2013J       31604      F
# 4      4         AAA             2013J       32885      F
#
#                  region      highest_education imd_band age_band  \
# 0   East Anglian Region       HE Qualification  90-100%     55<=
# 1              Scotland       HE Qualification   20-30%    35-55
# 2  North Western Region  A Level or Equivalent   30-40%    35-55
# 3     South East Region  A Level or Equivalent   50-60%    35-55
# 4  West Midlands Region     Lower Than A Level   50-60%     0-35
#
#    num_of_prev_attempts  studied_credits disability  mean_clicks  sum_clicks  \
# 0                     0              240          N     4.765306       934.0
# 1                     0               60          N     3.337209      1435.0
# 2                     0               60          Y     3.697368       281.0
# 3                     0               60          N     3.254902      2158.0
# 4                     0               60          N     2.937500      1034.0
#
#   final_result
# 0         Pass
# 1         Pass
# 2    Withdrawn
# 3         Pass
# 4         Pass

# %%
dataset_demographic = student_course_info[['code_module','code_presentation','region','highest_education','imd_band','num_of_prev_attempts','studied_credits','disability','final_result']]
dataset_demographic.to_csv('../data/dataset_demographic.csv')
dataset_demographic.head()
# Out:
#   code_module code_presentation                region      highest_education  \
# 0         AAA             2013J   East Anglian Region       HE Qualification
# 1         AAA             2013J              Scotland       HE Qualification
# 2         AAA             2013J  North Western Region  A Level or Equivalent
# 3         AAA             2013J     South East Region  A Level or Equivalent
# 4         AAA             2013J  West Midlands Region     Lower Than A Level
#
#   imd_band  num_of_prev_attempts  studied_credits disability final_result
# 0  90-100%                     0              240          N         Pass
# 1   20-30%                     0               60          N         Pass
# 2   30-40%                     0               60          Y    Withdrawn
# 3   50-60%                     0               60          N         Pass
# 4   50-60%                     0               60          N         Pass

# %%
dataset_student_clicks = student_course_info[['code_module','code_presentation','id_student','gender','region','highest_education','imd_band','num_of_prev_attempts','studied_credits',
                                              'disability','sum_clicks','mean_clicks','final_result']]
dataset_student_clicks.to_csv('../data/dataset_student_clicks.csv')
dataset_student_clicks.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band  num_of_prev_attempts  studied_credits  \
# 0       HE Qualification  90-100%                     0              240
# 1       HE Qualification   20-30%                     0               60
# 2  A Level or Equivalent   30-40%                     0               60
# 3  A Level or Equivalent   50-60%                     0               60
# 4     Lower Than A Level   50-60%                     0               60
#
#   disability  sum_clicks  mean_clicks final_result
# 0          N       934.0     4.765306         Pass
# 1          N      1435.0     3.337209         Pass
# 2          Y       281.0     3.697368    Withdrawn
# 3          N      2158.0     3.254902         Pass
# 4          N      1034.0     2.937500         Pass

# %% [markdown]
# ### Calculating Assessments scores

# %%
#adding some more columns
assessments_stats = assessments.groupby(['code_module','code_presentation']).agg({'weight' : 'sum'})
assessments_stats.reset_index(level=[0,1], inplace=True)
assessments_stats.head()
# Out:
#   code_module code_presentation  weight
# 0         AAA             2013J   200.0
# 1         AAA             2014J   200.0
# 2         BBB             2013B   200.0
# 3         BBB             2013J   200.0
# 4         BBB             2014B   200.0

# %%
assessments_stats.columns = ['code_module','code_presentation','total_marks']
assessments_stats = pd.merge(assessments, assessments_stats, how='left', on=['code_module','code_presentation'])
assessments_stats['percent_of_total'] = np.divide(assessments_stats['weight'],assessments_stats['total_marks'])*100
assessments_stats.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight  \
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
#
#    total_marks  percent_of_total
# 0        200.0               5.0
# 1        200.0              10.0
# 2        200.0              10.0
# 3        200.0              10.0
# 4        200.0              15.0

# %%
assessments_stats = assessments_stats.groupby(['code_module','code_presentation']).apply(compute_weighted_sum, 'percent_of_total', 'weight_in_total')
assessments_stats.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight  \
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
#
#    total_marks  percent_of_total  weight_in_total
# 0        200.0               5.0              5.0
# 1        200.0              10.0             15.0
# 2        200.0              10.0             25.0
# 3        200.0              10.0             35.0
# 4        200.0              15.0             50.0

# %%
student_assessments_all = pd.merge(student_assessment, assessments_stats, how = 'outer', on='id_assessment' )
student_assessments_all.isnull().sum()
# Out:
# id_assessment           0
# id_student             18
# date_submitted         18
# is_banked              18
# score                 191
# code_module             0
# code_presentation       0
# assessment_type         0
# date                 2873
# weight                  0
# total_marks             0
# percent_of_total        0
# weight_in_total         0
# dtype: int64

# %%
#assessments_stats.groupby(['code_module','code_presentation']).size()

student_assessments_all = student_assessments_all.dropna()
student_assessments_all['score'] = np.where(student_assessments_all['score'] == '?', '0', student_assessments_all['score'])
student_assessments_all['score'] = pd.to_numeric(student_assessments_all['score'])
student_assessments_all['assessment_result'] = np.where(student_assessments_all['score'] >= 40, 1, 0)
student_assessments_all['score_weight'] = np.divide(student_assessments_all['score'],100)*student_assessments_all['percent_of_total']
# student_assessments_all = student_assessments_all.dropna()
student_assessments_all = student_assessments_all.groupby(['code_module','code_presentation','id_student']).apply(compute_weighted_sum,'score_weight', 'score_in_total')
student_assessments_all = student_assessments_all[['code_module','code_presentation','id_student','id_assessment','assessment_type','date','date_submitted','is_banked',
                                                   'score','weight','percent_of_total','score_weight','weight_in_total','score_in_total','total_marks','assessment_result']]
#student_assessments_all[student_assessments_all['id_student'] == 63400]

student_assessments_all = pd.merge(student_assessments_all, student_info[['id_student','final_result']], on='id_student')
student_assessments_all[student_assessments_all['id_student'] == 63400]
# Out:
#    code_module code_presentation  id_student  id_assessment assessment_type  \
# 65         AAA             2013J     63400.0           1752             TMA
# 66         AAA             2013J     63400.0           1753             TMA
# 67         AAA             2013J     63400.0           1754             TMA
# 68         AAA             2013J     63400.0           1755             TMA
# 69         AAA             2013J     63400.0           1756             TMA
#
#      date  date_submitted  is_banked  score  weight  percent_of_total  \
# 65   19.0            19.0        0.0   83.0    10.0               5.0
# 66   54.0            54.0        0.0   42.0    20.0              10.0
# 67  117.0           117.0        0.0   78.0    20.0              10.0
# 68  166.0           166.0        0.0   76.0    20.0              10.0
# 69  215.0           215.0        0.0   79.0    30.0              15.0
#
#     score_weight  weight_in_total  score_in_total  total_marks  \
# 65          4.15              5.0            4.15        200.0
# 66          4.20             15.0            8.35        200.0
# 67          7.80             25.0           16.15        200.0
# 68          7.60             35.0           23.75        200.0
# 69         11.85             50.0           35.60        200.0
#
#     assessment_result final_result
# 65                  1         Pass
# 66                  1         Pass
# 67                  1         Pass
# 68                  1         Pass
# 69                  1         Pass

# %%
student_assessments_all.head()
# Out:
#   code_module code_presentation  id_student  id_assessment assessment_type  \
# 0         AAA             2013J     11391.0           1752             TMA
# 1         AAA             2013J     11391.0           1753             TMA
# 2         AAA             2013J     11391.0           1754             TMA
# 3         AAA             2013J     11391.0           1755             TMA
# 4         AAA             2013J     11391.0           1756             TMA
#
#     date  date_submitted  is_banked  score  weight  percent_of_total  \
# 0   19.0            18.0        0.0   78.0    10.0               5.0
# 1   54.0            53.0        0.0   85.0    20.0              10.0
# 2  117.0           115.0        0.0   80.0    20.0              10.0
# 3  166.0           164.0        0.0   85.0    20.0              10.0
# 4  215.0           212.0        0.0   82.0    30.0              15.0
#
#    score_weight  weight_in_total  score_in_total  total_marks  \
# 0           3.9              5.0             3.9        200.0
# 1           8.5             15.0            12.4        200.0
# 2           8.0             25.0            20.4        200.0
# 3           8.5             35.0            28.9        200.0
# 4          12.3             50.0            41.2        200.0
#
#    assessment_result final_result
# 0                  1         Pass
# 1                  1         Pass
# 2                  1         Pass
# 3                  1         Pass
# 4                  1         Pass

# %%
student_assessments_data = student_assessments_all[['code_module','code_presentation','id_student','id_assessment','assessment_type','is_banked','date','date_submitted','score','weight',
                                                    'weight_in_total','score_in_total','assessment_result','final_result']]
student_assessments_data.to_csv('../data/dataset_student_assessments.csv')
student_assessments_data[student_assessments_data['id_student'] == 63400]
student_assessments_data.shape
# Out:
# (203074, 14)

# %%
student_demographic_vle_clicks = dataset_student_clicks[['id_student','gender','region','highest_education','imd_band','num_of_prev_attempts','studied_credits','disability','sum_clicks',
                                                         'mean_clicks','final_result']]
student_data_final = pd.merge(student_demographic_vle_clicks, student_assessments_data, on=['id_student','final_result'])
student_data_final = student_data_final[['code_module', 'code_presentation', 'id_student', 'gender', 'region', 'highest_education', 'imd_band','num_of_prev_attempts', 'studied_credits', 
                                         'disability', 'sum_clicks', 'mean_clicks', 'id_assessment', 'assessment_type', 'is_banked', 'date', 'date_submitted', 'score', 'weight',
                                         'weight_in_total','score_in_total', 'assessment_result', 'final_result']]
#student_data_final.columns
student_data_final.to_csv('../data/dataset_student_final.csv')
student_data_final[student_data_final['id_student'] == 63400]
student_data_final.loc[:,{'id_student','highest_education','sum_clicks'}].head(10)
# Out:
#    sum_clicks  id_student highest_education
# 0       934.0       11391  HE Qualification
# 1       934.0       11391  HE Qualification
# 2       934.0       11391  HE Qualification
# 3       934.0       11391  HE Qualification
# 4       934.0       11391  HE Qualification
# 5      1435.0       28400  HE Qualification
# 6      1435.0       28400  HE Qualification
# 7      1435.0       28400  HE Qualification
# 8      1435.0       28400  HE Qualification
# 9      1435.0       28400  HE Qualification

# %%
student_data_final
# Out:
#        code_module code_presentation  id_student gender                region  \
# 0              AAA             2013J       11391      M   East Anglian Region
# 1              AAA             2013J       11391      M   East Anglian Region
# 2              AAA             2013J       11391      M   East Anglian Region
# 3              AAA             2013J       11391      M   East Anglian Region
# 4              AAA             2013J       11391      M   East Anglian Region
# 5              AAA             2013J       28400      F              Scotland
# 6              AAA             2013J       28400      F              Scotland
# 7              AAA             2013J       28400      F              Scotland
# 8              AAA             2013J       28400      F              Scotland
# 9              AAA             2013J       28400      F              Scotland
# 10             AAA             2013J       31604      F     South East Region
# 11             AAA             2013J       31604      F     South East Region
# 12             AAA             2013J       31604      F     South East Region
# 13             AAA             2013J       31604      F     South East Region
# 14             AAA             2013J       31604      F     South East Region
# 15             AAA             2013J       32885      F  West Midlands Region
# 16             AAA             2013J       32885      F  West Midlands Region
# 17             AAA             2013J       32885      F  West Midlands Region
# 18             AAA             2013J       32885      F  West Midlands Region
# 19             AAA             2013J       32885      F  West Midlands Region
# 20             AAA             2013J       38053      M                 Wales
# 21             AAA             2013J       38053      M                 Wales
# 22             AAA             2013J       38053      M                 Wales
# 23             AAA             2013J       38053      M                 Wales
# 24             AAA             2013J       38053      M                 Wales
# 25             AAA             2013J       45462      M              Scotland
# 26             AAA             2013J       45462      M              Scotland
# 27             AAA             2013J       45462      M              Scotland
# 28             AAA             2013J       45462      M              Scotland
# 29             AAA             2013J       45462      M              Scotland
# ...            ...               ...         ...    ...                   ...
# 230704         GGG             2014J     2620947      F              Scotland
# 230705         GGG             2014J     2620947      F              Scotland
# 230706         GGG             2014J     2620947      F              Scotland
# 230707         GGG             2014J     2645731      F   East Anglian Region
# 230708         GGG             2014J     2645731      F   East Anglian Region
# 230709         GGG             2014J     2645731      F   East Anglian Region
# 230710         GGG             2014J     2645731      F   East Anglian Region
# 230711         GGG             2014J     2645731      F   East Anglian Region
# 230712         GGG             2014J     2645731      F   East Anglian Region
# 230713         GGG             2014J     2645731      F   East Anglian Region
# 230714         GGG             2014J     2645731      F   East Anglian Region
# 230715         GGG             2014J     2645731      F   East Anglian Region
# 230716         GGG             2014J     2648187      F          South Region
# 230717         GGG             2014J     2648187      F          South Region
# 230718         GGG             2014J     2648187      F          South Region
# 230719         GGG             2014J     2648187      F          South Region
# 230720         GGG             2014J     2648187      F          South Region
# 230721         GGG             2014J     2648187      F          South Region
# 230722         GGG             2014J     2648187      F          South Region
# 230723         GGG             2014J     2648187      F          South Region
# 230724         GGG             2014J     2648187      F          South Region
# 230725         GGG             2014J     2679821      F     South East Region
# 230726         GGG             2014J     2679821      F     South East Region
# 230727         GGG             2014J     2684003      F      Yorkshire Region
# 230728         GGG             2014J     2684003      F      Yorkshire Region
# 230729         GGG             2014J     2684003      F      Yorkshire Region
# 230730         GGG             2014J     2684003      F      Yorkshire Region
# 230731         GGG             2014J     2684003      F      Yorkshire Region
# 230732         GGG             2014J     2684003      F      Yorkshire Region
# 230733         GGG             2014J     2684003      F      Yorkshire Region
#
#             highest_education imd_band  num_of_prev_attempts  studied_credits  \
# 0            HE Qualification  90-100%                     0              240
# 1            HE Qualification  90-100%                     0              240
# 2            HE Qualification  90-100%                     0              240
# 3            HE Qualification  90-100%                     0              240
# 4            HE Qualification  90-100%                     0              240
# 5            HE Qualification   20-30%                     0               60
# 6            HE Qualification   20-30%                     0               60
# 7            HE Qualification   20-30%                     0               60
# 8            HE Qualification   20-30%                     0               60
# 9            HE Qualification   20-30%                     0               60
# 10      A Level or Equivalent   50-60%                     0               60
# 11      A Level or Equivalent   50-60%                     0               60
# 12      A Level or Equivalent   50-60%                     0               60
# 13      A Level or Equivalent   50-60%                     0               60
# 14      A Level or Equivalent   50-60%                     0               60
# 15         Lower Than A Level   50-60%                     0               60
# 16         Lower Than A Level   50-60%                     0               60
# 17         Lower Than A Level   50-60%                     0               60
# 18         Lower Than A Level   50-60%                     0               60
# 19         Lower Than A Level   50-60%                     0               60
# 20      A Level or Equivalent   80-90%                     0               60
# 21      A Level or Equivalent   80-90%                     0               60
# 22      A Level or Equivalent   80-90%                     0               60
# 23      A Level or Equivalent   80-90%                     0               60
# 24      A Level or Equivalent   80-90%                     0               60
# 25           HE Qualification   30-40%                     0               60
# 26           HE Qualification   30-40%                     0               60
# 27           HE Qualification   30-40%                     0               60
# 28           HE Qualification   30-40%                     0               60
# 29           HE Qualification   30-40%                     0               60
# ...                       ...      ...                   ...              ...
# 230704  A Level or Equivalent   80-90%                     0               30
# 230705  A Level or Equivalent   80-90%                     0               30
# 230706  A Level or Equivalent   80-90%                     0               30
# 230707     Lower Than A Level   40-50%                     0               30
# 230708     Lower Than A Level   40-50%                     0               30
# 230709     Lower Than A Level   40-50%                     0               30
# 230710     Lower Than A Level   40-50%                     0               30
# 230711     Lower Than A Level   40-50%                     0               30
# 230712     Lower Than A Level   40-50%                     0               30
# 230713     Lower Than A Level   40-50%                     0               30
# 230714     Lower Than A Level   40-50%                     0               30
# 230715     Lower Than A Level   40-50%                     0               30
# 230716  A Level or Equivalent   20-30%                     0               30
# 230717  A Level or Equivalent   20-30%                     0               30
# 230718  A Level or Equivalent   20-30%                     0               30
# 230719  A Level or Equivalent   20-30%                     0               30
# 230720  A Level or Equivalent   20-30%                     0               30
# 230721  A Level or Equivalent   20-30%                     0               30
# 230722  A Level or Equivalent   20-30%                     0               30
# 230723  A Level or Equivalent   20-30%                     0               30
# 230724  A Level or Equivalent   20-30%                     0               30
# 230725     Lower Than A Level  90-100%                     0               30
# 230726     Lower Than A Level  90-100%                     0               30
# 230727       HE Qualification   50-60%                     0               30
# 230728       HE Qualification   50-60%                     0               30
# 230729       HE Qualification   50-60%                     0               30
# 230730       HE Qualification   50-60%                     0               30
# 230731       HE Qualification   50-60%                     0               30
# 230732       HE Qualification   50-60%                     0               30
# 230733       HE Qualification   50-60%                     0               30
#
#        disability  ...  assessment_type  is_banked   date date_submitted  \
# 0               N  ...              TMA        0.0   19.0           18.0
# 1               N  ...              TMA        0.0   54.0           53.0
# 2               N  ...              TMA        0.0  117.0          115.0
# 3               N  ...              TMA        0.0  166.0          164.0
# 4               N  ...              TMA        0.0  215.0          212.0
# 5               N  ...              TMA        0.0   19.0           22.0
# 6               N  ...              TMA        0.0   54.0           52.0
# 7               N  ...              TMA        0.0  117.0          121.0
# 8               N  ...              TMA        0.0  166.0          164.0
# 9               N  ...              TMA        0.0  215.0          212.0
# 10              N  ...              TMA        0.0   19.0           17.0
# 11              N  ...              TMA        0.0   54.0           51.0
# 12              N  ...              TMA        0.0  117.0          115.0
# 13              N  ...              TMA        0.0  166.0          165.0
# 14              N  ...              TMA        0.0  215.0          213.0
# 15              N  ...              TMA        0.0   19.0           26.0
# 16              N  ...              TMA        0.0   54.0           75.0
# 17              N  ...              TMA        0.0  117.0          124.0
# 18              N  ...              TMA        0.0  166.0          181.0
# 19              N  ...              TMA        0.0  215.0          222.0
# 20              N  ...              TMA        0.0   19.0           19.0
# 21              N  ...              TMA        0.0   54.0           64.0
# 22              N  ...              TMA        0.0  117.0          117.0
# 23              N  ...              TMA        0.0  166.0          166.0
# 24              N  ...              TMA        0.0  215.0          215.0
# 25              N  ...              TMA        0.0   19.0           20.0
# 26              N  ...              TMA        0.0   54.0           54.0
# 27              N  ...              TMA        0.0  117.0          117.0
# 28              N  ...              TMA        0.0  166.0          166.0
# 29              N  ...              TMA        0.0  215.0          216.0
# ...           ...  ...              ...        ...    ...            ...
# 230704          Y  ...              CMA        0.0  229.0          215.0
# 230705          Y  ...              CMA        0.0  229.0          220.0
# 230706          Y  ...              CMA        0.0  229.0          222.0
# 230707          N  ...              TMA        0.0   61.0           68.0
# 230708          N  ...              TMA        0.0  124.0          121.0
# 230709          N  ...              TMA        0.0  173.0          177.0
# 230710          N  ...              CMA        0.0  229.0          111.0
# 230711          N  ...              CMA        0.0  229.0          152.0
# 230712          N  ...              CMA        0.0  229.0          161.0
# 230713          N  ...              CMA        0.0  229.0          200.0
# 230714          N  ...              CMA        0.0  229.0          200.0
# 230715          N  ...              CMA        0.0  229.0          216.0
# 230716          Y  ...              TMA        0.0   61.0           50.0
# 230717          Y  ...              TMA        0.0  124.0          106.0
# 230718          Y  ...              TMA        0.0  173.0          172.0
# 230719          Y  ...              CMA        0.0  229.0           95.0
# 230720          Y  ...              CMA        0.0  229.0          128.0
# 230721          Y  ...              CMA        0.0  229.0          151.0
# 230722          Y  ...              CMA        0.0  229.0          200.0
# 230723          Y  ...              CMA        0.0  229.0          207.0
# 230724          Y  ...              CMA        0.0  229.0          215.0
# 230725          N  ...              TMA        0.0   61.0           56.0
# 230726          N  ...              CMA        0.0  229.0           75.0
# 230727          N  ...              TMA        0.0   61.0           37.0
# 230728          N  ...              TMA        0.0  124.0          114.0
# 230729          N  ...              TMA        0.0  173.0          169.0
# 230730          N  ...              CMA        0.0  229.0           73.0
# 230731          N  ...              CMA        0.0  229.0          150.0
# 230732          N  ...              CMA        0.0  229.0          172.0
# 230733          N  ...              CMA        0.0  229.0          206.0
#
#         score  weight  weight_in_total  score_in_total  assessment_result  \
# 0        78.0    10.0              5.0            3.90                  1
# 1        85.0    20.0             15.0           12.40                  1
# 2        80.0    20.0             25.0           20.40                  1
# 3        85.0    20.0             35.0           28.90                  1
# 4        82.0    30.0             50.0           41.20                  1
# 5        70.0    10.0              5.0            3.50                  1
# 6        68.0    20.0             15.0           10.30                  1
# 7        70.0    20.0             25.0           17.30                  1
# 8        64.0    20.0             35.0           23.70                  1
# 9        60.0    30.0             50.0           32.70                  1
# 10       72.0    10.0              5.0            3.60                  1
# 11       71.0    20.0             15.0           10.70                  1
# 12       74.0    20.0             25.0           18.10                  1
# 13       88.0    20.0             35.0           26.90                  1
# 14       75.0    30.0             50.0           38.15                  1
# 15       69.0    10.0              5.0            3.45                  1
# 16       30.0    20.0             15.0            6.45                  0
# 17       63.0    20.0             25.0           12.75                  1
# 18       35.0    20.0             35.0           16.25                  0
# 19       75.0    30.0             50.0           27.50                  1
# 20       79.0    10.0              5.0            3.95                  1
# 21       69.0    20.0             15.0           10.85                  1
# 22       74.0    20.0             25.0           18.25                  1
# 23       50.0    20.0             35.0           23.25                  1
# 24       68.0    30.0             50.0           33.45                  1
# 25       70.0    10.0              5.0            3.50                  1
# 26       65.0    20.0             15.0           10.00                  1
# 27       62.0    20.0             25.0           16.20                  1
# 28       75.0    20.0             35.0           23.70                  1
# 29       68.0    30.0             50.0           33.90                  1
# ...       ...     ...              ...             ...                ...
# 230704   80.0     0.0              0.0            0.00                  1
# 230705  100.0     0.0              0.0            0.00                  1
# 230706   80.0     0.0              0.0            0.00                  1
# 230707   80.0     0.0              0.0            0.00                  1
# 230708   81.0     0.0              0.0            0.00                  1
# 230709   72.0     0.0              0.0            0.00                  1
# 230710  100.0     0.0              0.0            0.00                  1
# 230711   80.0     0.0              0.0            0.00                  1
# 230712  100.0     0.0              0.0            0.00                  1
# 230713  100.0     0.0              0.0            0.00                  1
# 230714  100.0     0.0              0.0            0.00                  1
# 230715   80.0     0.0              0.0            0.00                  1
# 230716   65.0     0.0              0.0            0.00                  1
# 230717   75.0     0.0              0.0            0.00                  1
# 230718   70.0     0.0              0.0            0.00                  1
# 230719   60.0     0.0              0.0            0.00                  1
# 230720   60.0     0.0              0.0            0.00                  1
# 230721   80.0     0.0              0.0            0.00                  1
# 230722  100.0     0.0              0.0            0.00                  1
# 230723  100.0     0.0              0.0            0.00                  1
# 230724   80.0     0.0              0.0            0.00                  1
# 230725   83.0     0.0              0.0            0.00                  1
# 230726  100.0     0.0              0.0            0.00                  1
# 230727   80.0     0.0              0.0            0.00                  1
# 230728   80.0     0.0              0.0            0.00                  1
# 230729   60.0     0.0              0.0            0.00                  1
# 230730  100.0     0.0              0.0            0.00                  1
# 230731   60.0     0.0              0.0            0.00                  1
# 230732  100.0     0.0              0.0            0.00                  1
# 230733  100.0     0.0              0.0            0.00                  1
#
#         final_result
# 0               Pass
# 1               Pass
# 2               Pass
# 3               Pass
# 4               Pass
# 5               Pass
# 6               Pass
# 7               Pass
# 8               Pass
# 9               Pass
# 10              Pass
# 11              Pass
# 12              Pass
# 13              Pass
# 14              Pass
# 15              Pass
# 16              Pass
# 17              Pass
# 18              Pass
# 19              Pass
# 20              Pass
# 21              Pass
# 22              Pass
# 23              Pass
# 24              Pass
# 25              Pass
# 26              Pass
# 27              Pass
# 28              Pass
# 29              Pass
# ...              ...
# 230704   Distinction
# 230705   Distinction
# 230706   Distinction
# 230707   Distinction
# 230708   Distinction
# 230709   Distinction
# 230710   Distinction
# 230711   Distinction
# 230712   Distinction
# 230713   Distinction
# 230714   Distinction
# 230715   Distinction
# 230716          Pass
# 230717          Pass
# 230718          Pass
# 230719          Pass
# 230720          Pass
# 230721          Pass
# 230722          Pass
# 230723          Pass
# 230724          Pass
# 230725     Withdrawn
# 230726     Withdrawn
# 230727   Distinction
# 230728   Distinction
# 230729   Distinction
# 230730   Distinction
# 230731   Distinction
# 230732   Distinction
# 230733   Distinction
#
# [230734 rows x 23 columns]

# %%
allwithdrawn=student_data_final[student_data_final['final_result']=='Withdrawn']
allwithdrawn
# Out:
#        code_module code_presentation  id_student gender                region  \
# 70             AAA             2013J       65002      F   East Anglian Region
# 71             AAA             2013J       65002      F   East Anglian Region
# 72             AAA             2014J       65002      F   East Anglian Region
# 73             AAA             2014J       65002      F   East Anglian Region
# 103            AAA             2013J       94961      M          South Region
# 104            AAA             2014J       94961      M          South Region
# 105            AAA             2014J       94961      M          South Region
# 106            AAA             2014J       94961      M          South Region
# 107            AAA             2014J       94961      M          South Region
# 108            AAA             2014J       94961      M          South Region
# 139            AAA             2013J      106247      M          South Region
# 140            AAA             2013J      106247      M          South Region
# 141            AAA             2013J      106247      M          South Region
# 195            AAA             2013J      129955      M  West Midlands Region
# 196            AAA             2013J      129955      M  West Midlands Region
# 197            AAA             2013J      129955      M  West Midlands Region
# 198            AAA             2013J      129955      M  West Midlands Region
# 199            AAA             2013J      129955      M  West Midlands Region
# 200            AAA             2013J      129955      M  West Midlands Region
# 201            AAA             2014J      129955      M  West Midlands Region
# 202            AAA             2014J      129955      M  West Midlands Region
# 203            AAA             2014J      129955      M  West Midlands Region
# 204            AAA             2014J      129955      M  West Midlands Region
# 205            AAA             2014J      129955      M  West Midlands Region
# 206            AAA             2014J      129955      M  West Midlands Region
# 207            AAA             2013J      129955      M  West Midlands Region
# 208            AAA             2013J      129955      M  West Midlands Region
# 209            AAA             2013J      129955      M  West Midlands Region
# 210            AAA             2013J      129955      M  West Midlands Region
# 211            AAA             2013J      129955      M  West Midlands Region
# ...            ...               ...         ...    ...                   ...
# 229403         GGG             2014J      681195      M              Scotland
# 229442         GGG             2014J      681791      M   East Anglian Region
# 229503         GGG             2014J      682481      F   East Anglian Region
# 229504         GGG             2014J      682481      F   East Anglian Region
# 229505         GGG             2014J      682481      F   East Anglian Region
# 229506         GGG             2014J      682481      F   East Anglian Region
# 229541         GGG             2014J      683299      F              Scotland
# 229657         GGG             2014J      684987      M              Scotland
# 229658         GGG             2014J      684987      M              Scotland
# 229659         GGG             2014J      684987      M              Scotland
# 230077         GGG             2014J      690895      F              Scotland
# 230137         GGG             2014J      691577      M   East Anglian Region
# 230138         GGG             2014J      691577      M   East Anglian Region
# 230300         GGG             2014J      694416      M                 Wales
# 230301         GGG             2014J      694416      M                 Wales
# 230302         GGG             2014J      694416      M                 Wales
# 230553         GGG             2014J     1841303      F         London Region
# 230554         GGG             2014J     1841303      F         London Region
# 230604         GGG             2014J     2203216      F                 Wales
# 230605         GGG             2014J     2214722      F              Scotland
# 230606         GGG             2014J     2214722      F              Scotland
# 230607         GGG             2014J     2214722      F              Scotland
# 230608         GGG             2014J     2214722      F              Scotland
# 230609         GGG             2014J     2214722      F              Scotland
# 230610         GGG             2014J     2214722      F              Scotland
# 230645         GGG             2014J     2342238      M               Ireland
# 230646         GGG             2014J     2357806      F               Ireland
# 230647         GGG             2014J     2357806      F               Ireland
# 230725         GGG             2014J     2679821      F     South East Region
# 230726         GGG             2014J     2679821      F     South East Region
#
#             highest_education imd_band  num_of_prev_attempts  studied_credits  \
# 70      A Level or Equivalent   70-80%                     0               60
# 71      A Level or Equivalent   70-80%                     0               60
# 72      A Level or Equivalent   70-80%                     0               60
# 73      A Level or Equivalent   70-80%                     0               60
# 103        Lower Than A Level   70-80%                     0               60
# 104        Lower Than A Level   70-80%                     0               60
# 105        Lower Than A Level   70-80%                     0               60
# 106        Lower Than A Level   70-80%                     0               60
# 107        Lower Than A Level   70-80%                     0               60
# 108        Lower Than A Level   70-80%                     0               60
# 139          HE Qualification   80-90%                     0               60
# 140          HE Qualification   80-90%                     0               60
# 141          HE Qualification   80-90%                     0               60
# 195     A Level or Equivalent   50-60%                     0               60
# 196     A Level or Equivalent   50-60%                     0               60
# 197     A Level or Equivalent   50-60%                     0               60
# 198     A Level or Equivalent   50-60%                     0               60
# 199     A Level or Equivalent   50-60%                     0               60
# 200     A Level or Equivalent   50-60%                     0               60
# 201     A Level or Equivalent   50-60%                     0               60
# 202     A Level or Equivalent   50-60%                     0               60
# 203     A Level or Equivalent   50-60%                     0               60
# 204     A Level or Equivalent   50-60%                     0               60
# 205     A Level or Equivalent   50-60%                     0               60
# 206     A Level or Equivalent   50-60%                     0               60
# 207     A Level or Equivalent   50-60%                     1               60
# 208     A Level or Equivalent   50-60%                     1               60
# 209     A Level or Equivalent   50-60%                     1               60
# 210     A Level or Equivalent   50-60%                     1               60
# 211     A Level or Equivalent   50-60%                     1               60
# ...                       ...      ...                   ...              ...
# 229403        No Formal quals   30-40%                     0               30
# 229442     Lower Than A Level   70-80%                     0               30
# 229503     Lower Than A Level   60-70%                     0               30
# 229504     Lower Than A Level   60-70%                     0               30
# 229505     Lower Than A Level   60-70%                     0               30
# 229506     Lower Than A Level   60-70%                     0               30
# 229541     Lower Than A Level    0-10%                     0               30
# 229657     Lower Than A Level   60-70%                     0               30
# 229658     Lower Than A Level   60-70%                     0               30
# 229659     Lower Than A Level   60-70%                     0               30
# 230077  A Level or Equivalent    10-20                     0               30
# 230137     Lower Than A Level   60-70%                     0               30
# 230138     Lower Than A Level   60-70%                     0               30
# 230300     Lower Than A Level    0-10%                     0               30
# 230301     Lower Than A Level    0-10%                     0               30
# 230302     Lower Than A Level    0-10%                     0               30
# 230553     Lower Than A Level    10-20                     0               30
# 230554     Lower Than A Level    10-20                     0               30
# 230604  A Level or Equivalent   80-90%                     0               30
# 230605  A Level or Equivalent   70-80%                     0               30
# 230606  A Level or Equivalent   70-80%                     0               30
# 230607  A Level or Equivalent   70-80%                     0               30
# 230608  A Level or Equivalent   70-80%                     0               30
# 230609  A Level or Equivalent   70-80%                     0               30
# 230610  A Level or Equivalent   70-80%                     0               30
# 230645       HE Qualification   80-90%                     0               30
# 230646     Lower Than A Level   40-50%                     0               30
# 230647     Lower Than A Level   40-50%                     0               30
# 230725     Lower Than A Level  90-100%                     0               30
# 230726     Lower Than A Level  90-100%                     0               30
#
#        disability  ...  assessment_type  is_banked   date date_submitted  \
# 70              N  ...              TMA        0.0   19.0           17.0
# 71              N  ...              TMA        0.0   54.0           51.0
# 72              N  ...              TMA        1.0   19.0           -1.0
# 73              N  ...              TMA        1.0   54.0           -1.0
# 103             N  ...              TMA        0.0   19.0           17.0
# 104             N  ...              TMA        1.0   19.0           -1.0
# 105             N  ...              TMA        0.0   54.0           51.0
# 106             N  ...              TMA        0.0  117.0          122.0
# 107             N  ...              TMA        0.0  166.0          166.0
# 108             N  ...              TMA        0.0  215.0          211.0
# 139             N  ...              TMA        0.0   19.0           32.0
# 140             N  ...              TMA        0.0   54.0           64.0
# 141             N  ...              TMA        0.0  117.0          115.0
# 195             N  ...              TMA        0.0   19.0           18.0
# 196             N  ...              TMA        0.0   19.0           18.0
# 197             N  ...              TMA        0.0   54.0           54.0
# 198             N  ...              TMA        0.0   54.0           54.0
# 199             N  ...              TMA        0.0  117.0          127.0
# 200             N  ...              TMA        0.0  117.0          127.0
# 201             N  ...              TMA        1.0   19.0           -1.0
# 202             N  ...              TMA        1.0   19.0           -1.0
# 203             N  ...              TMA        1.0   54.0           -1.0
# 204             N  ...              TMA        1.0   54.0           -1.0
# 205             N  ...              TMA        1.0  117.0           -1.0
# 206             N  ...              TMA        1.0  117.0           -1.0
# 207             N  ...              TMA        0.0   19.0           18.0
# 208             N  ...              TMA        0.0   19.0           18.0
# 209             N  ...              TMA        0.0   54.0           54.0
# 210             N  ...              TMA        0.0   54.0           54.0
# 211             N  ...              TMA        0.0  117.0          127.0
# ...           ...  ...              ...        ...    ...            ...
# 229403          N  ...              TMA        0.0  124.0           82.0
# 229442          N  ...              TMA        0.0   61.0           58.0
# 229503          N  ...              TMA        0.0   61.0           59.0
# 229504          N  ...              TMA        0.0  124.0          121.0
# 229505          N  ...              CMA        0.0  229.0           76.0
# 229506          N  ...              CMA        0.0  229.0          128.0
# 229541          N  ...              TMA        0.0   61.0           68.0
# 229657          N  ...              TMA        0.0   61.0           42.0
# 229658          N  ...              TMA        0.0  124.0          142.0
# 229659          N  ...              CMA        0.0  229.0           90.0
# 230077          N  ...              TMA        0.0   61.0           44.0
# 230137          Y  ...              TMA        0.0   61.0           59.0
# 230138          Y  ...              CMA        0.0  229.0           97.0
# 230300          Y  ...              TMA        0.0   61.0           62.0
# 230301          Y  ...              TMA        0.0  124.0          125.0
# 230302          Y  ...              TMA        0.0  173.0          168.0
# 230553          N  ...              TMA        0.0   61.0           58.0
# 230554          N  ...              CMA        0.0  229.0           90.0
# 230604          N  ...              TMA        0.0   61.0           67.0
# 230605          N  ...              TMA        0.0   61.0           58.0
# 230606          N  ...              TMA        0.0  124.0          129.0
# 230607          N  ...              TMA        0.0  173.0          169.0
# 230608          N  ...              CMA        0.0  229.0          121.0
# 230609          N  ...              CMA        0.0  229.0          137.0
# 230610          N  ...              CMA        0.0  229.0          157.0
# 230645          N  ...              TMA        0.0   61.0           57.0
# 230646          N  ...              TMA        0.0   61.0           54.0
# 230647          N  ...              CMA        0.0  229.0           73.0
# 230725          N  ...              TMA        0.0   61.0           56.0
# 230726          N  ...              CMA        0.0  229.0           75.0
#
#         score  weight  weight_in_total  score_in_total  assessment_result  \
# 70       66.0    10.0              5.0            3.30                  1
# 71       68.0    20.0             15.0           10.10                  1
# 72       66.0    10.0              5.0            3.30                  1
# 73       68.0    20.0             15.0           10.10                  1
# 103      74.0    10.0              5.0            3.70                  1
# 104      74.0    10.0              5.0            3.70                  1
# 105      67.0    20.0             15.0           10.40                  1
# 106      57.0    20.0             25.0           16.10                  1
# 107      65.0    20.0             35.0           22.60                  1
# 108      55.0    30.0             50.0           30.85                  1
# 139      67.0    10.0              5.0            3.35                  1
# 140      66.0    20.0             15.0            9.95                  1
# 141      47.0    20.0             25.0           14.65                  1
# 195      85.0    10.0              5.0            4.25                  1
# 196      85.0    10.0              5.0            4.25                  1
# 197      82.0    20.0             15.0           12.45                  1
# 198      82.0    20.0             15.0           12.45                  1
# 199      76.0    20.0             25.0           20.05                  1
# 200      76.0    20.0             25.0           20.05                  1
# 201      85.0    10.0              5.0            4.25                  1
# 202      85.0    10.0              5.0            4.25                  1
# 203      82.0    20.0             15.0           12.45                  1
# 204      82.0    20.0             15.0           12.45                  1
# 205      76.0    20.0             25.0           20.05                  1
# 206      76.0    20.0             25.0           20.05                  1
# 207      85.0    10.0              5.0            4.25                  1
# 208      85.0    10.0              5.0            4.25                  1
# 209      82.0    20.0             15.0           12.45                  1
# 210      82.0    20.0             15.0           12.45                  1
# 211      76.0    20.0             25.0           20.05                  1
# ...       ...     ...              ...             ...                ...
# 229403   65.0     0.0              0.0            0.00                  1
# 229442   75.0     0.0              0.0            0.00                  1
# 229503   70.0     0.0              0.0            0.00                  1
# 229504   75.0     0.0              0.0            0.00                  1
# 229505  100.0     0.0              0.0            0.00                  1
# 229506  100.0     0.0              0.0            0.00                  1
# 229541   45.0     0.0              0.0            0.00                  1
# 229657   85.0     0.0              0.0            0.00                  1
# 229658   85.0     0.0              0.0            0.00                  1
# 229659  100.0     0.0              0.0            0.00                  1
# 230077   65.0     0.0              0.0            0.00                  1
# 230137   60.0     0.0              0.0            0.00                  1
# 230138  100.0     0.0              0.0            0.00                  1
# 230300   37.0     0.0              0.0            0.00                  0
# 230301   35.0     0.0              0.0            0.00                  0
# 230302   35.0     0.0              0.0            0.00                  0
# 230553   67.0     0.0              0.0            0.00                  1
# 230554   80.0     0.0              0.0            0.00                  1
# 230604   55.0     0.0              0.0            0.00                  1
# 230605   93.0     0.0              0.0            0.00                  1
# 230606   95.0     0.0              0.0            0.00                  1
# 230607   85.0     0.0              0.0            0.00                  1
# 230608  100.0     0.0              0.0            0.00                  1
# 230609  100.0     0.0              0.0            0.00                  1
# 230610   80.0     0.0              0.0            0.00                  1
# 230645   50.0     0.0              0.0            0.00                  1
# 230646   73.0     0.0              0.0            0.00                  1
# 230647   80.0     0.0              0.0            0.00                  1
# 230725   83.0     0.0              0.0            0.00                  1
# 230726  100.0     0.0              0.0            0.00                  1
#
#         final_result
# 70         Withdrawn
# 71         Withdrawn
# 72         Withdrawn
# 73         Withdrawn
# 103        Withdrawn
# 104        Withdrawn
# 105        Withdrawn
# 106        Withdrawn
# 107        Withdrawn
# 108        Withdrawn
# 139        Withdrawn
# 140        Withdrawn
# 141        Withdrawn
# 195        Withdrawn
# 196        Withdrawn
# 197        Withdrawn
# 198        Withdrawn
# 199        Withdrawn
# 200        Withdrawn
# 201        Withdrawn
# 202        Withdrawn
# 203        Withdrawn
# 204        Withdrawn
# 205        Withdrawn
# 206        Withdrawn
# 207        Withdrawn
# 208        Withdrawn
# 209        Withdrawn
# 210        Withdrawn
# 211        Withdrawn
# ...              ...
# 229403     Withdrawn
# 229442     Withdrawn
# 229503     Withdrawn
# 229504     Withdrawn
# 229505     Withdrawn
# 229506     Withdrawn
# 229541     Withdrawn
# 229657     Withdrawn
# 229658     Withdrawn
# 229659     Withdrawn
# 230077     Withdrawn
# 230137     Withdrawn
# 230138     Withdrawn
# 230300     Withdrawn
# 230301     Withdrawn
# 230302     Withdrawn
# 230553     Withdrawn
# 230554     Withdrawn
# 230604     Withdrawn
# 230605     Withdrawn
# 230606     Withdrawn
# 230607     Withdrawn
# 230608     Withdrawn
# 230609     Withdrawn
# 230610     Withdrawn
# 230645     Withdrawn
# 230646     Withdrawn
# 230647     Withdrawn
# 230725     Withdrawn
# 230726     Withdrawn
#
# [33167 rows x 23 columns]

# %%
allwithdrawn.shape
# Out:
# (33167, 23)

# %%
plt.figure(figsize=(10,10))
sns.countplot(student_data_final.final_result)
plt.xticks(rotation = 90)
plt.show()

# %%
dft = {'Pass':25095, 'Withdrawn':4693, 'Fail':4688, 'Distinction':5919}
df = pd.DataFrame(data=dft,index=dft.keys())
df.head()
# Out:
#               Pass  Withdrawn  Fail  Distinction
# Pass         25095       4693  4688         5919
# Withdrawn    25095       4693  4688         5919
# Fail         25095       4693  4688         5919
# Distinction  25095       4693  4688         5919
